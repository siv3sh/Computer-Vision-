# %% [markdown]
# COMPUTER VISION

# %% [markdown]
# opencv is open source computer vision library
# Fast and efficient image processing, computer vision, and machine learning.
# Read, write, and display images, Apply filters (blur, sharpening, edge detection),Perform
# image transformations (rotation, resizing, perspective change).
# Feature detection (Harris Corner, SIFT, SURF), Read, write, and display images.
# Apply filters (blur, sharpening, edge detection).
# Perform image transformations (rotation, resizing, perspective change).
# Feature detection (Harris Corner, SIFT, SURF).
# Face, object, and motion detection.
# Face, object, and motion detection.

# %%
import cv2
import numpy as np

# %%
from matplotlib import pyplot as plt #primarily used to create visualizations and plots

# %%
img = cv2.imread('/Users/siv3sh/Downloads/Dash_Tail UI Concept.jpg') #Syntax: cv2.imread(path, flag)
#flag: It specifies the way in which image should be read. It’s default value is
#cv2.IMREAD_COLOR

# %%
plt.imshow(img)
print(img)
# Out:
# [[[185 181 163]
#   [185 181 163]
#   [185 181 163]
#   ...
#   [176 163 147]
#   [176 163 147]
#   [176 163 147]]
#
#  [[163 159 141]
#   [163 159 141]
#   [162 158 140]
#   ...
#   [150 137 121]
#   [150 137 121]
#   [150 137 121]]
#
#  [[166 162 144]
#   [166 162 144]
#   [165 161 143]
#   ...
#   [151 138 122]
#   [151 138 122]
#   [151 138 122]]
#
#  ...
#
#  [[145 131 113]
#   [145 131 113]
#   [145 131 113]
#   ...
#   [ 78  70  63]
#   [ 80  72  65]
#   [ 83  75  68]]
#
#  [[145 131 113]
#   [145 131 113]
#   [145 131 113]
#   ...
#   [ 79  71  64]
#   [ 80  72  65]
#   [ 83  75  68]]
#
#  [[144 130 112]
#   [145 131 113]
#   [145 131 113]
#   ...
#   [ 63  55  48]
#   [ 71  63  56]
#   [ 73  65  58]]]

# %%
print("Shape:", img.shape)
# Out:
# File name (736, 736, 3)

# %%
# 2. Reading and writing image Using ImageIO

# %%
import imageio as iio

# %%
img1 = iio.imread('/Users/siv3sh/Downloads/Dash_Tail UI Concept.jpg')
# Out:
# /var/folders/65/hh4dl_ys1wj4vcmzjpy1wy2w0000gn/T/ipykernel_28835/1974140492.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img1 = iio.imread('/Users/siv3sh/Downloads/Dash_Tail UI Concept.jpg')

# %%
iio.imwrite("g4g.png", img1)# write it in a new format

# %%
import matplotlib.image as mpimg# importing matplotlib modules

# %%
img2 = mpimg.imread("g4g.png")

# %%
plt.imshow(img2)

# %%
import PIL#Using PIL : PIL is the Python Imaging Library

# %%
from PIL import Image

# %%
img3 = Image.open("g4g.png")

# %%
img3.show()

# %%
pip install scikit-image
# Out:
# ...
#
# [notice] A new release of pip is available: 24.1.2 -> 25.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from skimage import io, filters

# Purpose: Advanced image processing and computer vision.
#Key Features:
#Filters (Gaussian, Sobel, Prewitt).
# Feature extraction (edges, corners, blobs).
#Segmentation (watershed, thresholding).


image = io.imread("g4g.png", as_gray=True) # Load grayscale image
edges = filters.sobel(image) # Apply Sobel edge detection
io.imshow(image)
plt.show()

# %%
print(img3.format)
# Out:
# PNG

# %%
print(img3.mode)
# Out:
# RGB

# %%
print("Filename:", img3.filename)
# Out:
# Filename: /Users/siv3sh/g4g.png

# %%
print("Size: ",img.size)
# Out:
# Size:  1625088

# %%
print("Height: ", img3.height)
# Out:
# Height:  736

# %%
print("Width: ", img3.width)
# Out:
# Width:  736

# %%
import cv2
import numpy as np

# %%
img4 = cv2.imread('/Users/siv3sh/Downloads/Dash_Tail UI Concept.jpg')
pixel= img4[100,100]
print (pixel)
# accessing only blue pixel
blue = img4[100,100,0] # if we specify 1 then we can access green pixel and 2 is for red
print(blue)
# Out:
# [163 155 138]
# 163

# %%
#converting image into different formats
#Opencv Support Below Image file format to read &amp; write(Save):

# %%
# Windows bitmaps – *.bmp, *.dib
# JPEG files – *.jpeg, *.jpg, *.jpe
# JPEG 2000 files – *.jp2
# Portable Network Graphics – *.png
# Portable image format – *.pbm, *.pgm, *.ppm
# Sun rasters – *.sr, *.ras
# TIFF files – *.tiff, *.tif

# %%
img5 = cv2.imread('/Users/siv3sh/Downloads/Dash_Tail UI Concept.jpg')
cv2.imwrite("newimg5.png",img5)
# Out:
# True
